# %%
import time
from src.node_parser.text.sentence import SentenceSplitter 
from src.reader.dir_reader import DirectoryReader
# Out:
# /home/hungnq/anaconda3/envs/fusedchat/lib/python3.9/site-packages/pydantic/_migration.py:283: UserWarning: `pydantic.error_wrappers:ValidationError` has been moved to `pydantic:ValidationError`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')
# /home/hungnq/anaconda3/envs/fusedchat/lib/python3.9/site-packages/pydantic/_migration.py:283: UserWarning: `pydantic.generics:GenericModel` has been moved to `pydantic.BaseModel`.
#   warnings.warn(f'`{import_path}` has been moved to `{new_location}`.')
# /home/hungnq/anaconda3/envs/fusedchat/lib/python3.9/site-packages/pydantic/_internal/_config.py:321: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# /home/hungnq/anaconda3/envs/fusedchat/lib/python3.9/site-packages/pydantic/_internal/_fields.py:149: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %% [markdown]
# ## Reader and Splitter

# %%
splitter = SentenceSplitter(
    separator=" ",
    chunk_size=200,
    chunk_overlap=20,
    paragraph_separator="\n\n\n",
    secondary_chunking_regex="[^.。？！]+[.。？！]?"
)
splitter
# Out:
# SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<src.callbacks.callback_manager.CallbackManager object at 0x7fe1542f2280>, id_func=<function default_id_func at 0x7fe1540dc940>, chunk_size=200, chunk_overlap=20, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^.。？！]+[.。？！]?', tokenizer=<bound method PreTrainedTokenizerBase.encode of BertTokenizerFast(name_or_path='BAAI/bge-base-en-v1.5', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)>)

# %%
import glob
files = glob.glob("/home/hungnq/hungnq_2/backend_db/backendDB/data/*.docx")

docs = DirectoryReader(
    input_files=files
).load_data(show_progress=True)
# Out:
# Loading files: 100%|██████████| 2/2 [00:00<00:00, 101.00file/s]

# %%
docs[0].dict()
# Out:
# {'id_': '29334164-2c9d-4d54-a027-de5c0b088be0',
#  'embedding': None,
#  'metadata': {'file_name': 'Phương pháp kiến tạo xã hội.docx',
#   'file_path': '/home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx',
#   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
#   'file_size': 17805,
#   'creation_date': '2024-01-30',
#   'last_modified_date': '2024-01-30',
#   'last_accessed_date': '2024-01-30'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'hash': '',
#  'text': 'PHƯƠNG PHÁP KIẾN TẠO XÃ HỘI\n\nÝ nghĩa: \n\nKiến tạo: tích cực học tập để xây dựng kiến thức kỹ năng cho bản thân\n\nXã hội: học nhóm, học qua cộng đồng, qua các nguồn thông tin khác.\n\nNhiệm vụ của sinh viên\n\nTrước khi môn học bắt đầu: Tìm hiểu môn học\n\nNắm được các yêu cầu của môn học\n\nLưu ý những buổi học thep pp KTXH\n\nTrước hoặc trong buổi học kiến tạo: Chuẩn bị\n\nChủ động tìm hiểu chủ đề liên quan tới câu hỏi kiến tạo của buổi học\n\nThảo luận, trao đổi trong nhóm để cùng chuẩn bị bài trình bày theo câu hỏi kiến tạo được phân công\n\nLựa chọn người trình bày, người phát biểu\n\nTrong buổi học, dưới sự điều hành của giảng viên\n\nLàm việc theo nhóm\n\nTrình bày nhóm và tìm cách trả lời các câu hỏi của các nhóm khác\n\nLắng nghe trình bày của nhóm khác, trao đổi và trả lời câu hỏi\n\nCho điểm của nhóm đối với bài trình bày của nhóm khác theo tiêu chỉ quy định; nắm các ý chính mà giảng viên đã kết nối.\n\nCuối buổi học: Tổng hợp\n\nGhi nhận những vấn đề mà GV đã hệ thống hoá và bổ sung (nếu cần)\n\nChấm điểm các thành viên khác trong nhóm theo tiêu chí quy định\n\nTiếp nhận nhiệm vụ nhóm mới cho buổi sau\n\nĐánh giá kết quả (các đầu điểm)\n\nĐiểm trình bày của nhóm (tối đa 4 điểm):\n\nDo các nhóm khác và GV (nếu cần) chấm\n\nTheo 4 tiêu chí, mỗi tiêu chí 1 điểm:\n\n+ Đúng giờ\n\n+ Đúng chủ đề yêu cầu\n\n+ Cách trình bày hấp dẫn\n\n+ Nhiều thông tin mới hữu ích\n\nĐiểm do bài trình bày của nhóm tính bằng trung bình cộng điểm do các nhóm khác và GV (nếu có) chấm cho bài trình bày theo các tiêu chí trên.\n\nĐiểm trình bày của nhóm trong buổc học tính bằng trùng bình cộng điểm các bài trình bày nhóm trong buổi học.\n\nĐiểm phản biện của nhóm (tối đa 3 điểm):\n\nDo GV chấm có sự xác nhận của các nhóm SV\n\nCách tính:\n\nMột câu hỏi hay của nhóm: cộng tối đa 1 điểm\n\nMột trả lời hay của nhóm: cộng tối đa 1 điểm\n\nNhóm không chấm đểm bài trình bày của nhóm khác: trừ 1 điểm\n\nĐiểm phản biện của nhóm đối với mỗi bài trình bày của nhóm khác được tính tích luỹ nhưng tối đa là 3 điểm\n\nĐiểm phản biện của nhóm trong buổi học bằng trung bình cộng điểm phản biện của nhóm đối với tất cả các bài trình bày của nhóm khác trong buổi học.\n\nĐiểm cá nhân sinh viên trong nhóm (tối đa 3 điểm):\n\nDo các SV khác trong cùng nhóm chấm điểm\n\nTheo 3 tiêu chí, mỗi tiêu chí tối đa 1 điểm:\n\n+ Chăm chỉ\n\n+ Giỏi\n\n+ Dễ cộng tác\n\n\n\nĐiểm của sinh viên theo phương pháp KTXN:\n\nĐược tính bằng tổng điểm: điểm trình bày trong nhóm, điểm phản biện của nhóm và điểm cá nhân sinh viên trong nhóm.',
#  'start_char_idx': None,
#  'end_char_idx': None,
#  'text_template': '{metadata_str}\n\n{content}',
#  'metadata_template': '{key}: {value}',
#  'metadata_seperator': '\n'}

# %%
docs[0].text
# Out:
# 'PHƯƠNG PHÁP KIẾN TẠO XÃ HỘI\n\nÝ nghĩa: \n\nKiến tạo: tích cực học tập để xây dựng kiến thức kỹ năng cho bản thân\n\nXã hội: học nhóm, học qua cộng đồng, qua các nguồn thông tin khác.\n\nNhiệm vụ của sinh viên\n\nTrước khi môn học bắt đầu: Tìm hiểu môn học\n\nNắm được các yêu cầu của môn học\n\nLưu ý những buổi học thep pp KTXH\n\nTrước hoặc trong buổi học kiến tạo: Chuẩn bị\n\nChủ động tìm hiểu chủ đề liên quan tới câu hỏi kiến tạo của buổi học\n\nThảo luận, trao đổi trong nhóm để cùng chuẩn bị bài trình bày theo câu hỏi kiến tạo được phân công\n\nLựa chọn người trình bày, người phát biểu\n\nTrong buổi học, dưới sự điều hành của giảng viên\n\nLàm việc theo nhóm\n\nTrình bày nhóm và tìm cách trả lời các câu hỏi của các nhóm khác\n\nLắng nghe trình bày của nhóm khác, trao đổi và trả lời câu hỏi\n\nCho điểm của nhóm đối với bài trình bày của nhóm khác theo tiêu chỉ quy định; nắm các ý chính mà giảng viên đã kết nối.\n\nCuối buổi học: Tổng hợp\n\nGhi nhận những vấn đề mà GV đã hệ thống hoá và bổ sung (nếu cần)\n\nChấm điểm các thành viên khác trong nhóm theo tiêu chí quy định\n\nTiếp nhận nhiệm vụ nhóm mới cho buổi sau\n\nĐánh giá kết quả (các đầu điểm)\n\nĐiểm trình bày của nhóm (tối đa 4 điểm):\n\nDo các nhóm khác và GV (nếu cần) chấm\n\nTheo 4 tiêu chí, mỗi tiêu chí 1 điểm:\n\n+ Đúng giờ\n\n+ Đúng chủ đề yêu cầu\n\n+ Cách trình bày hấp dẫn\n\n+ Nhiều thông tin mới hữu ích\n\nĐiểm do bài trình bày của nhóm tính bằng trung bình cộng điểm do các nhóm khác và GV (nếu có) chấm cho bài trình bày theo các tiêu chí trên.\n\nĐiểm trình bày của nhóm trong buổc học tính bằng trùng bình cộng điểm các bài trình bày nhóm trong buổi học.\n\nĐiểm phản biện của nhóm (tối đa 3 điểm):\n\nDo GV chấm có sự xác nhận của các nhóm SV\n\nCách tính:\n\nMột câu hỏi hay của nhóm: cộng tối đa 1 điểm\n\nMột trả lời hay của nhóm: cộng tối đa 1 điểm\n\nNhóm không chấm đểm bài trình bày của nhóm khác: trừ 1 điểm\n\nĐiểm phản biện của nhóm đối với mỗi bài trình bày của nhóm khác được tính tích luỹ nhưng tối đa là 3 điểm\n\nĐiểm phản biện của nhóm trong buổi học bằng trung bình cộng điểm phản biện của nhóm đối với tất cả các bài trình bày của nhóm khác trong buổi học.\n\nĐiểm cá nhân sinh viên trong nhóm (tối đa 3 điểm):\n\nDo các SV khác trong cùng nhóm chấm điểm\n\nTheo 3 tiêu chí, mỗi tiêu chí tối đa 1 điểm:\n\n+ Chăm chỉ\n\n+ Giỏi\n\n+ Dễ cộng tác\n\n\n\nĐiểm của sinh viên theo phương pháp KTXN:\n\nĐược tính bằng tổng điểm: điểm trình bày trong nhóm, điểm phản biện của nhóm và điểm cá nhân sinh viên trong nhóm.'

# %%
from src.node.types import MetadataMode
chunks = splitter.get_nodes_from_documents(documents=docs)
for chunk in chunks:
    print("-"*10)
    print(chunk.get_content(metadata_mode=MetadataMode.ALL))
# Out:
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# PHƯƠNG PHÁP KIẾN TẠO XÃ HỘI
#
# Ý nghĩa:
#
# Kiến tạo: tích cực học tập để xây dựng kiến thức kỹ năng cho bản thân
#
# Xã hội: học nhóm, học qua cộng đồng, qua các nguồn thông tin khác.
#
# Nhiệm vụ của sinh viên
#
# Trước khi môn học bắt đầu: Tìm hiểu môn học
#
# Nắm được các yêu cầu của môn
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# các yêu cầu của môn học
#
# Lưu ý những buổi học thep pp KTXH
#
# Trước hoặc trong buổi học kiến tạo: Chuẩn bị
#
# Chủ động tìm hiểu chủ đề liên quan tới câu hỏi kiến tạo của buổi học
#
# Thảo luận, trao đổi
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# học
#
# Thảo luận, trao đổi trong nhóm để cùng chuẩn bị bài trình bày theo câu hỏi kiến tạo được phân công
#
# Lựa chọn người trình bày, người phát biểu
#
# Trong buổi học, dưới sự điều hành của giảng viên
#
# Làm việc
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# của giảng viên
#
# Làm việc theo nhóm
#
# Trình bày nhóm và tìm cách trả lời các câu hỏi của các nhóm khác
#
# Lắng nghe trình bày của nhóm khác, trao đổi và trả lời câu hỏi
#
# Cho điểm của nhóm đối với
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# của nhóm đối với bài trình bày của nhóm khác theo tiêu chỉ quy định; nắm các ý chính mà giảng viên đã kết nối.
#
# Cuối buổi học: Tổng hợp
#
# Ghi nhận những vấn đề mà GV đã hệ thống hoá
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# GV đã hệ thống hoá và bổ sung (nếu cần)
#
# Chấm điểm các thành viên khác trong nhóm theo tiêu chí quy định
#
# Tiếp nhận nhiệm vụ nhóm mới cho buổi sau
#
# Đánh giá kết quả (các đầu điểm)
#
# Điểm trình
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# đầu điểm)
#
# Điểm trình bày của nhóm (tối đa 4 điểm):
#
# Do các nhóm khác và GV (nếu cần) chấm
#
# Theo 4 tiêu chí, mỗi tiêu chí 1 điểm:
#
# + Đúng giờ
#
# + Đúng chủ đề yêu cầu
#
# + Cách trình bày
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# yêu cầu
#
# + Cách trình bày hấp dẫn
#
# + Nhiều thông tin mới hữu ích
#
# Điểm do bài trình bày của nhóm tính bằng trung bình cộng điểm do các nhóm khác và GV (nếu có) chấm cho bài trình bày theo các tiêu
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# trình bày theo các tiêu chí trên.
#
# Điểm trình bày của nhóm trong buổc học tính bằng trùng bình cộng điểm các bài trình bày nhóm trong buổi học.
#
# Điểm phản biện của nhóm (tối đa 3 điểm):
#
# Do GV chấm có sự xác nhận của các nhóm SV
#
# Cách
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# của các nhóm SV
#
# Cách tính:
#
# Một câu hỏi hay của nhóm: cộng tối đa 1 điểm
#
# Một trả lời hay của nhóm: cộng tối đa 1 điểm
#
# Nhóm không chấm đểm bài trình bày của nhóm khác: trừ 1
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# nhóm khác: trừ 1 điểm
#
# Điểm phản biện của nhóm đối với mỗi bài trình bày của nhóm khác được tính tích luỹ nhưng tối đa là 3 điểm
#
# Điểm phản biện của nhóm trong buổi học bằng trung bình
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# buổi học bằng trung bình cộng điểm phản biện của nhóm đối với tất cả các bài trình bày của nhóm khác trong buổi học.
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# khác trong buổi học.
#
# Điểm cá nhân sinh viên trong nhóm (tối đa 3 điểm):
#
# Do các SV khác trong cùng nhóm chấm điểm
#
# Theo 3 tiêu chí, mỗi tiêu chí tối đa 1 điểm:
#
# + Chăm chỉ
#
# + Giỏi
#
# + Dễ cộng tác
# ----------
# file_name: Phương pháp kiến tạo xã hội.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 17805
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Điểm của sinh viên theo phương pháp KTXN:
#
# Được tính bằng tổng điểm: điểm trình bày trong nhóm, điểm phản biện của nhóm và điểm cá nhân sinh viên trong nhóm.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# 33.
#
#
#
# CAPSTONE PROJECT REGISTER
#
#
#
# 	Class:                       Duration time:  from 1/1/2024  to 12/4/2024
#
# 			(*) Profession: <Artificial Intelligence> 	              Specialty:      <ES>
#
#        <IS>
#
#   <JS>
#
#
#
# (*) Kinds of person make registers:                  Lecturer:
#
# x                  Students
#
#
#
#
#
# 			1. Register information for supervisor (if have)
#
#
#
# 			Full name
#
# 			Phone
#
# 			E-Mail
#
# 			Title
#
# 			Supervisor 1
#
# 			Nguyễn Quốc Trung
#
# 			0979350707
#
# 			trungnq46@fe.edu.vn
#
# 			Mr.
#
# 			Supervisor 2
#
# 			Trương Hoàng Vinh
#
#
#
#
#
# 			Mr.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Supervisor 2
#
# 			Trương Hoàng Vinh
#
#
#
#
#
# 			Mr.
#
# 			2.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Supervisor 2
#
# 			Trương Hoàng Vinh
#
#
#
#
#
# 			Mr.
#
# 			2. Register information for students (if have)
#
#
#
# 			Full name
#
# 			Student code
#
# 			Phone
#
# 			E-mail
#
# 			Role in Group
#
# 			Student 1
#
# 			Phạm Minh Tuấn
#
# 			SE160561
#
# 			0354551714
#
# 			tuanpmse160561@fpt.edu.vn
#
# 			Leader
#
# 			Student 2
#
# 			Nguyễn Quốc Hùng
#
# 			SE162007
#
# 			0937737658
#
# 			hungnqse162007@fpt.edu.vn
#
# 			Member
#
# 			Student 3
#
# 			Lê Phước Gia Thịnh
#
# 			SE161384
#
# 			0966506908
#
# 			thinhlpgse161384@fpt.edu.vn
#
# 			Member
#
#
#
# 			3.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Register content of Capstone Project
#
# 			(*) 3.1. Capstone Project name:English: Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension
#
# 			Vietnamese: Hệ Thống Hỏi Đáp Đa Ngôn Ngữ với Giọng Nói Tự Nhiên Như Con Người.
#
# 			Abbreviation: NLP-Voice
#
# 			Description: The project aims to harness the power of pre-trained Large Language Models (LLMs) to develop a robust and versatile system for bilingual question-answering and human-level naturalness Text-to-Speech (TTS) applications.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# The focus will be on creating an efficient and trustworthy system that supports the Vietnamese language, facilitating bilingual text and speech interactions.
#
# 			Objectives:
#
# 			Bilingual Support for QA System: Develop a system capable of handling questions and generating responses in both English and Vietnamese.
#
# 			Retrieval Augmented Generation Pipeline (RAG): Design a tailored retrieval system that supports QA System for efficiently fetching relevant information to user’s questions from user’s private documents.
#
# 			Text-to-Speech module: Integrate a TTS module that converts textual responses into spoken language.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# It replicates human speech patterns, tones, and nuances for a more natural and engaging interaction.
#
# 			Speech-to-Text API module: Integrate a STT module using existing APIs that converts spoken questions of the user into textual input for the QA model.
#
# 			Demo Web App: Develop a minimal graphical user interface.
#
# 			Business Cases:
#
# 			Q&A Module: Customized question-answering system for responding to specialized knowledge (on private documents without worrying of sensitive information leakage). It can extend the capability of the Q&A system in various knowledge-based fields including legal, researching paper.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Voice Module: This module enables users to hand-freely interact with the Q&A system. This versatile module  helps users not need to chat every word but let this whole framework process itself. This combination also may help individuals with disabilities.
#
# 			Proposed Solution for QA Module:
#
# 			Data Generation and Collection: Gather a diverse dataset of instruction-tuning comprising English questions and answers. Using our self-made pipeline translator to translate datasets to Vietnamese and combine with large open source  synthesis instruction data like MBZUAI/Bactrian-X.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# And a mix of QA dataset augmented with both vietnamese and english documents to better robust the model for both languages.
#
# 			Data Processing: Preprocess and clean the dataset for training purposes. Implement language-specific tokenization and preprocessing techniques.
#
# 			Framework Architecture Development:
#
# 			We propose the creation of a QA system that accepts questions in both languages.
#
# 			In the QA system, the user’s query is paraphrased to many sub-queries to make it more specific or clearer.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Then using a custom RAG system to retrieve relevant documents and format them into LLM generating answers. Our choice of language models includes state-of-the-art large language models (LLMs) with up to 7 billion parameters like LLAMA2.
#
# 			In the RAG system, we concate the above QA module and API Retriever into one consistent pipeline. We find any available retrievers specializing in Vietnamese and  evaluate model ability on Vietnamese query based on some well-known metrics.
#
# 			Finally, the generated answer can be used directly as output, or be transferred into voice output if the user preferred.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Fine-Tuning Technique: Utilize a pre-trained LLM and fine-tune it on the bilingual dataset. Explore techniques for bilingual adaptation to ensure optimal performance in both languages.
#
# 			Evaluation: Access the system's performance through rigorous evaluation metrics, such as F1 score, Rouge’s family score, BLEU score for QA system. We also use submetrics such as Answer Relevant, Faithfulness,... from RAGAS framework to ensure these generated answers on time.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# On top of that, we also use Retriever metrics for this evaluation including Mean Reciprocal Rank (MRR) and Hit Rate.
#
# 			Demo Web App: Develop a minimal graphical user interface with Gradio library for easy interaction.
#
# 			Proposed Solution for TTS Module:
#
# 			Data Collection: Downloading audio with subtitles from voice actors or celebrities on YouTube.
#
# 			Data Processing: The voice segment will undergo noise reduction and silence removal processing. The text segment will be normalized and subjected to spell-checking, ensuring accuracy and quality. Missing text will be manually added.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Missing text will be manually added.
#
# 			Architecture: We will implement one of the two following approaches:
#
# 			Approach 1 - Two-Stage Pipeline: Fine-tuning a Text-to-Speech module such as VITS or FastSpeech on a Vietnamese TTS dataset in the first stage. Combine it with a Voice Cloning (Speech-to-Speech) module such as Retrieval-Based Voice Conversion (RVC) in the second stage. The result of this pipeline provides a natural Text-to-Speech output with the ability to customize the voice according to user preferences.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Approach 2 - Zero-Shot End-to-End TTS Voice Cloning: Implement the state-of-the-art end-to-end text-to-speech system like Style TTS or XTTS with the zero-shot voice cloning capability.
#
# 			Evaluation: We employ the Mean Opinion Score of Naturalness (MOS-N) to gauge human-likeness of the synthesized speeches.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# We will design a survey where human evaluators listen to audio samples and rate voice quality based on naturalness and compare it with the output of popular TTS systems such as Google Translate, Bing Translator, FPT.AI and Vbee. The comprehensive definition of "naturalness" will be articulated by examining and synthesizing insights from prior research in order to provide a detailed and nuanced understanding of the concept.
#
# 			Demo: Develop a minimal graphical user interface with Gradio library for easy interaction.
#
# 			Proposed Solution for STT Module:
#
# 			We aim to leverage the capabilities of established APIs such as Google or Bing.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# By utilizing these pre-existing resources, we ensure a robust and reliable conversion of spoken language into text.
#
# 			It's essential to highlight that our approach for this module does not entail the development or introduction of new datasets or models.
#
# 			3.2 Main Proposal Content (Including Results and Products):
#
# 			a. Theory and Practice (Document):
#
# 			Key Theory: Ground the project in the foundational theories of natural language processing, reinforcement learning, bilingual adaptation and speech processing.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Application of Knowledge from Previous Courses: Students will apply their knowledge acquired from AIG201c, AIP39, AIL302m, DPL301m and NLP301c in the execution of this project. Leverage insights from previous courses on machine learning, deep learning, and natural language processing as well as extending for new Reinforcement Learning field.
#
# 			Research: The project involves the exploration of machine learning and deep learning models to augment the framework's performance.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Conduct an extensive literature review on state-of-the-art techniques in pre-trained LLMs bilingual applications as well as TTS applications.
#
# 			Utilized Artificial Intelligence Technologies:
#
# 			Programming Languages: Python.
#
# 			Frameworks: PyTorch, Hugging Face.
#
# 			Deployment: Github, Docker, Hugging Face Hub, Runpod, AWS (Lambda, S3, DynamoDB).
#
# 			Monitoring and Testing tools: TensorBoard, Wandb, Postman, Pytest.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Monitoring and Testing tools: TensorBoard, Wandb, Postman, Pytest.
#
# 			b. Products:
#
# 			Key Deliverables:
#
# 			Bilingual QA Module: Deploy API that takes in questions in English or Vietnamese and provides accurate and contextually relevant responses based on the documents provided by the user.
#
# 			Text-to-Speech Module: Deploy API that converts textual responses into spoken language in both English and Vietnamese, enhancing accessibility.
#
# 			A Demo Web Application that combines the two modules.
#
# 			Custom Retrieval System: A robust tailored system for efficient retrieval of information from both English and Vietnamese .
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# Bilingual Text Dataset: A curated dataset comprising English and Vietnamese questions and answers for training and evaluation.
#
# 			Vietnamese TTS Dataset: A curated dataset of Vietnamese speeches and transcripts.
#
# 			A comprehensive research paper detailing the project.
#
#
#
# 	4. Other comment (propose all relative thing if have)
#
# 	Students are willing to learn new research topics, especially machine learning and deep learning for NLP.
#
# 	Students are willing to work hard such as report every week with new progress, read and present knowledge from the documents in the field.
# ----------
# file_name: Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Spring2024_Hybrid Bilingual Question-Answering System with Human-Level Naturalness Text-to-Speech Extension_NLP-TTS_TrungNQ46.docx
# file_type: application/vnd.openxmlformats-officedocument.wordprocessingml.document
# file_size: 233883
# creation_date: 2024-01-30
# last_modified_date: 2024-01-30
# last_accessed_date: 2024-01-30
#
# There is at least one student in the group who has a solid background in software engineering for implementing the tool.
#
# 	The number of students for this project varies from 2 to 3. The project output may differ depending on this number.
#
#
#
# 			Supervisor (If have)
#
# 			 (Sign and full name)
#
# 			Ho Chi Minh city, date //2023
#
# 			On behalf of Registers
#
# 			(Sign and full name)
#
#
#
#
#
# 		11.14-BM/DH/HDCV/FU 1/0

# %% [markdown]
# ## test function split

# %%
test = '\n\nMột câu hỏi hay của nhóm: cộng tối đa 1 điểm\n\nMột trả lời hay của nhóm: cộng tối đa 1 điểm\n\nNhóm không chấm đểm bài trình bày của nhóm khác: trừ 1 điểm\n\nĐiểm phản biện của nhóm đối với mỗi bài trình bày của nhóm khác được tính tích luỹ nhưng tối đa là 3 điểm\n\nĐiểm phản biện của nhóm trong buổi học bằng trung bình cộng điểm phản biện của nhóm đối với tất cả các bài trình bày của nhóm khác trong buổi học.\n\nĐiểm cá nhân sinh viên trong nhóm (tối đa 3 điểm):\n\nDo các SV khác trong cùng nhóm chấm điểm\n\nTheo 3 tiêu chí, mỗi tiêu chí tối đa 1 điểm:\n\n+ Chăm chỉ\n\n+ Giỏi\n\n+ Dễ cộng tác\n\n\n\nĐiểm của sinh viên theo phương pháp KTXN:\n\nĐược tính bằng tổng điểm: điểm trình bày trong nhóm, điểm phản biện của nhóm và điểm cá nhân sinh viên trong nhóm.'

# %%
from typing import Callable, List
def split_text_keep_separator(text: str, separator: str) -> List[str]:
    """Split text with separator and keep the separator at the end of each split."""
    parts = text.split(separator)
    result = [separator + s if i > 0 else s for i, s in enumerate(parts)]
    return [s for s in result if s]


def split_by_sep(sep: str, keep_sep: bool = True) -> Callable[[str], List[str]]:
    """Split text by separator."""
    if keep_sep:
        return lambda text: split_text_keep_separator(text, sep)
    else:
        return lambda text: text.split(sep)

# %%
func = split_by_sep("\n\n\n")

# %%
splits = func(test)
splits
# Out:
# ['\n\nMột câu hỏi hay của nhóm: cộng tối đa 1 điểm\n\nMột trả lời hay của nhóm: cộng tối đa 1 điểm\n\nNhóm không chấm đểm bài trình bày của nhóm khác: trừ 1 điểm\n\nĐiểm phản biện của nhóm đối với mỗi bài trình bày của nhóm khác được tính tích luỹ nhưng tối đa là 3 điểm\n\nĐiểm phản biện của nhóm trong buổi học bằng trung bình cộng điểm phản biện của nhóm đối với tất cả các bài trình bày của nhóm khác trong buổi học.\n\nĐiểm cá nhân sinh viên trong nhóm (tối đa 3 điểm):\n\nDo các SV khác trong cùng nhóm chấm điểm\n\nTheo 3 tiêu chí, mỗi tiêu chí tối đa 1 điểm:\n\n+ Chăm chỉ\n\n+ Giỏi\n\n+ Dễ cộng tác',
#  '\n\n\n\nĐiểm của sinh viên theo phương pháp KTXN:\n\nĐược tính bằng tổng điểm: điểm trình bày trong nhóm, điểm phản biện của nhóm và điểm cá nhân sinh viên trong nhóm.']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-base-en-v1.5")
enc_func = tokenizer.encode
enc_func
# Out:
# <bound method PreTrainedTokenizerBase.encode of BertTokenizerFast(name_or_path='BAAI/bge-base-en-v1.5', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True)>

# %%
len(enc_func("file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx")), enc_func("file_path: /home/hungnq/hungnq_2/backend_db/backendDB/data/Phương pháp kiến tạo xã hội.docx")
# Out:
# (45,
#  [101,
#   5371,
#   1035,
#   4130,
#   1024,
#   1013,
#   2188,
#   1013,
#   5112,
#   2078,
#   4160,
#   1013,
#   5112,
#   2078,
#   4160,
#   1035,
#   1016,
#   1013,
#   2067,
#   10497,
#   1035,
#   16962,
#   1013,
#   2067,
#   10497,
#   18939,
#   1013,
#   2951,
#   1013,
#   6887,
#   19098,
#   3070,
#   6887,
#   9331,
#   11382,
#   2368,
#   20216,
#   1060,
#   2050,
#   7570,
#   2072,
#   1012,
#   9986,
#   2595,
#   102])
